# %% [markdown]
# <a href="https://colab.research.google.com/github/abusaleh917/Practice/blob/main/Notebook_for_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## .ipynb => Interactive Python Notebook

print("Abu Saleh")
print("This is Python Programming.")
print("Actualy the word PYTHON is use as name of a snake.","\n""But here we use it as name of a programing language")
print( "In print function we can do some mathe also.like")
print("5+6=",5+6)
print('Subtruction of 200 and 50 is=',200-50)
print("60/6=",60/6)
# Out:
# Abu Saleh
# This is Python Programming.
# Actualy the word PYTHON is use as name of a snake.
# But here we use it as name of a programing language
# In print function we can do some mathe also.like
# 5+6= 11
# Subtruction of 200 and 50 is= 150
# 60/6= 10.0

# %%
## Printing with formatting

val1=567
val2=765
div=val2/val1
print("Floting result=",div)
div1=val2//val1
print("Integer result=", div1)
# Out:
# Floting result= 1.3492063492063493
# Integer result= 1

# %%
## Printing with formatting
var1 = 53.7
var3=89.34
sum=var1+var3
print("Result", sum)
print("Formeted result={:.4f}%".format(sum) )
print("sub=", var3-var1)
# Out:
# Result 143.04000000000002
# Formeted result=143.0400%
# sub= 35.64

# %%
## Printing different types of values

print("Skill, Morph")  # Displaying a string

name = "Mr. Person"
age = 21
print("Name:", name, "Age:", age)

num1 = 5
num2 = 7
print("Num1 =", num1, "Num2 =", num2, "Sum =", num1 + num2)  # Printing variables and literals
# Out:
# Skill, Morph
# Name: Mr. Person Age: 21
# Num1 = 5 Num2 = 7 Sum = 12

# %%
## Printing with formatting

num1 = 145.89
num2 = 345.568

sum = num1 + num2
print("Value: {:.1f}%".format(sum))
print("{:.3f}".format(sum))
# Out:
# Value: 491.5%
# 491.458

# %%
## H1: Write a program to perform the subtraction, multipllication and division
var1=int(input())
var2=int(input())
sub=var1-var2
print("Subtraction of", var1, "and", var2, "is=" ,sub)
##Multiplication
pdt=var1*var2
print("Product of ", var1, "and", var2, "is=",pdt)
##Division
Div=var1/var2
print("Quotient=",Div)
# Out:
# 600
# 60
# Subtraction of 600 and 60 is= 540
# Product of  600 and 60 is= 36000
# Quotient= 10.0

# %%
dept = "Machine Learning" ##Assign value to variable
org = "Skill Morph"

print(dept)
# Out:
# Machine Learning

# %%
dept, org, batch = "Machine Learning", "Skill Morph", 1 ##Decalare multiple variables in a line

print(dept, "\t", org, "\t", batch)
# Out:
# Machine Learning 	 Skill Morph 	 1

# %%
## H2: Write a program to declare variables for id, name, batch, and hometown, and assign values, and finally print.
id = 1013
name = "Abu Saleh"
batch = "03"
hometown = "Barguna"
print("ID:",id,"\n" "Name:",name,"\n","Batch:",batch,"\n","Hometown:",hometown)
# Out:
# ID: 1013
# Name: Abu Saleh
#  Batch: 03
#  Hometown: Barguna

# %%
# Changing value of a variable

dept_name = 'Machine Learning'
print("Before: ", dept_name)

dept_name = 'Data Science'  # assigning a new value to dept_name

print("After: ", dept_name)
# Out:
# Before:  Machine Learning
# After:  Data Science

# %%
## H3: Write a program to change values of an integer variable
work_time='10am'
print("Today's work time is", work_time)
work_time='11am'
print("Tomorrow's work time is", work_time)
# Out:
# Today's work time is 10am
# Tomorrow's work time is 11am

# %%
# Variables and literals

num = 123.56

b = False

print(b)
# Out:
# False

# %%
x=122454.354
x1='12549'
x2=1234
x3="58665"
print(type(x), type(x1) )
print(type(x1))
print(type(x2))
print(type(x3))
sum=x2+int(x3)
print(sum)
# Out:
# <class 'float'> <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# 59899

# %%
##H4: Write a program to take two string numbers and convert them to integers using explicit type conversion.
a="654"
b="321"
print(type(a))
print(type(b))
a1=int(a)
b1=int(b)
print(type(a1))
print(type(b1))
sum=a1+b1
print(sum)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# 975

# %%
## H5: Write a program to calculate and print the average of the three numbers. Round the result to two decimal places.
a=input()
b=input()
c=input()
avg=(int(a)+int(b)+int(c))/3
print("Average of",a,",",b, "and", c,"is={:.2f}".format(avg))
# Out:
# 10
# 20
# 30
# Average of 10 , 20 and 30 is=20.00

# %%
## H6: Create a simple calculator that performs basic arithmetic operations (addition, subtraction, multiplication, division) based on user input.

# %%
## H8: Create a program that converts temperatures between Fahrenheit and Celsius based on user input.
print("If your input is Fahrenheit please type ""F"" otherwise type C")
Con=(input())
if Con == "F" or Con=="f":
  print("Temperature in Fahrenheit=")
  temp=int(input())
  celsius=(temp - 32) * 5/9
  print("Temparature in celsius=", celsius)
elif Con == "C" or Con== "c":
  print("Temparature in celsius=")
  temp=int(input())
  fahrenheit = (temp * 9/5) + 32
  print("Temparature in Fahrenheit=", fahrenheit)
else:
    print("input is Invalid")
# Out:
# If your input is Fahrenheit please type F otherwise type C
# o
# input is Invalid

# %%
## H9: Write a program that asks the user to enter three numbers and determines which one is the largest.
